# %%
import nltk

# %%
lst = [1,2,3,4,5]

# %%
print lst
# Out:
# [1, 2, 3, 4, 5]

# %%
print 'First element:' + str(lst[0])
# Out:
# First element:1

# %%
print 'last element:'+ str(lst[-1])
# Out:
# last element:5

# %%
print 'first three elements:'+str(lst[0:2])
# Out:
# first three elements:[1, 2]

# %%
print 'last three elements:'+ str(lst[-3:])
# Out:
# last three elements:[3, 4, 5]

# %%
print 'first element:'+str(lst[0])
# Out:
# first element:1

# %%
print 'first element:'+str(lst[0:])
# Out:
# first element:[1, 2, 3, 4, 5]

# %%
print 'first element:'+str(lst[0:1])
# Out:
# first element:[1]

# %%
print 'some elements:'+str(lst[3:5])
# Out:
# some elements:[4, 5]

# %%
dir(lst)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__delslice__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__setslice__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
maia = ['pink', 3,  'blue', 'smart', 10, 4, 6]

# %%
dir(maia)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__delslice__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__setslice__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
','.join(dir(maia))
# Out:
# '__add__,__class__,__contains__,__delattr__,__delitem__,__delslice__,__doc__,__eq__,__format__,__ge__,__getattribute__,__getitem__,__getslice__,__gt__,__hash__,__iadd__,__imul__,__init__,__iter__,__le__,__len__,__lt__,__mul__,__ne__,__new__,__reduce__,__reduce_ex__,__repr__,__reversed__,__rmul__,__setattr__,__setitem__,__setslice__,__sizeof__,__str__,__subclasshook__,append,count,extend,index,insert,pop,remove,reverse,sort'

# %%
help(maia.index)
# Out:
# Help on built-in function index:
#
# index(...)
#     L.index(value, [start, [stop]]) -> integer -- return first index of value.
#     Raises ValueError if the value is not present.

# %%
maia='maia eshte shpirti i vogel i mamit!\n'

# %%
print maia.split()
# Out:
# ['maia', 'eshte', 'shpirti', 'i', 'vogel', 'i', 'mamit!']

# %%
print maia.strip()
# Out:
# maia eshte shpirti i vogel i mamit!

# %%
maia11 ='maia eshte \n nje yll \n i vogel Maia \n ka sy blu \n shume te bukur!'

# %%
print maia11.strip()
# Out:
# maia eshte
#  nje yll
#  i vogel Maia
#  ka sy blu
#  shume te bukur!

# %%
print maia11.rstrip()
# Out:
# maia eshte
#  nje yll
#  i vogel Maia
#  ka sy blu
#  shume te bukur!

# %%
print maia11.lstrip()
# Out:
# maia eshte
#  nje yll
#  i vogel Maia
#  ka sy blu
#  shume te bukur!

# %%
print maia11.upper()
# Out:
# MAIA ESHTE
#  NJE YLL
#  I VOGEL MAIA
#  KA SY BLU
#  SHUME TE BUKUR!

# %%
bora3='nje fjali te gjate we si ne kohen e enverit kur ne vend te g-se perdornim dicka tjeter'

# %%
print bora3.replace('w','q')
# Out:
# nje fjali te gjate qe si ne kohen e enverit kur ne vend te g-se perdornim dicka tjeter

# %%
import re

# %%
if re.search('yll',maia11):
    print "we found yll"
else:
    print "no"
# Out:
# we found yll

# %%
print(maia11)
# Out:
# maia eshte
#  nje yll
#  i vogel Maia
#  ka sy blu
#  shume te bukur!

# %%
print re.findall('y',maia11)
# Out:
# ['y', 'y']

# %%
dt = open('Ch_01_dropbox.txt')
raw = dt.read()

# %%
print re.findall('knowledge', raw)
# Out:
# ['knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledg
# ...

# %%
if re.search('knowledge',raw):
    print "we found knowledge"
else:
    print "no"
# Out:
# we found knowledge

# %%
list = ['knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge']

# %%
#create a dictionary for maia 11
word_freq ={}
for tok in maia11.split():
    if tok in word_freq:
        word_freq[tok]+=1
    else:
        word_freq[tok]=1
print word_freq
# Out:
# {'eshte': 1, 'ka': 1, 'nje': 1, 'vogel': 1, 'i': 1, 'sy': 1, 'blu': 1, 'maia': 1, 'bukur!': 1, 'Maia': 1, 'yll': 1, 'te': 1, 'shume': 1}

# %%
#create a dictionary for chapter 01
word_freq={}
for tok in raw.split():
    if tok in word_freq:
        word_freq[tok]+=1
    else:
        word_freq[tok]=1
print word_freq
# Out:
# {'better,': 1, 'personally': 2, 'desirable': 1, 'four': 1, 'sleep': 3, 'texts,': 1, 'hanging': 1, 'consists': 3, 'whose': 1, '2012),': 1, '1.1:': 2, 'Ronald': 1, 'Western': 3, 'under': 7, 'League': 1, 'Carter,': 1, 'question,': 1, '\xe2\x80\x98how\xe2\x80\x99': 1, 'every': 4, 'govern': 1, 'vast': 1, 'Thomas': 4, 'objectivity': 1, 'skills': 1, 'companies': 1, 'solution': 1, 'Unanticipated': 1, 'Go': 1, 'provided': 1, 'front,': 1, 'enjoy': 1, 'her.': 1, 'created.': 1, 'tired': 1, 'Paradigm:': 1, 'guidelines': 4, 'direct': 2, 'further?': 1, 'likely': 3, 'follow': 3, 'rigorous': 1, 'estimated': 1, 'even': 5, 'established': 8, 'preferences': 4, 'incompatible': 1, 'terms,': 2, 'cooking': 1, 'reasoning': 11, 'understood,': 1, 'designing': 1, 'new': 47, 'seeks': 1, 'told': 1, '90).': 1, 'Sometimes': 2, 'simultaneously': 1, 'notions': 2, 'TT1': 1, 'men': 4, 'non-governmental': 1, 'here': 9, 'anthropology': 2, 'protection': 1, 'studio': 2, 'possibility': 1, '100': 1, 'interpret': 1, 'seek.': 1
# ...

# %%
#function that will generate a frequency distribution of a text
import sys
def wordfreq (raw):
    word_freq={}
    for tok in raw.split():
        if tok in word_freq:
            word_freq[tok]+=1
        else:
            word_freq[tok]=1
    print word_freq

# %%
wordfreq(maia11)
# Out:
# {'eshte': 1, 'ka': 1, 'nje': 1, 'vogel': 1, 'i': 1, 'sy': 1, 'blu': 1, 'maia': 1, 'bukur!': 1, 'Maia': 1, 'yll': 1, 'te': 1, 'shume': 1}

# %%
# urllib2 is use to download the html content of the web link
import urllib2
response = urllib2.urlopen('https://www.indeed.com')

# %%
#you can read the entire content of a file using read() method
html = response.read()

# %%
print len(html)
# Out:
# 50478

# %%
print (html)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>Job Search | Indeed</title>
# <meta name="description" content="Job Search by Indeed. Search millions of jobs from thousands of job boards, newspapers, classifieds and company websites on indeed.com">
# <meta name="keywords" content="job search, Indeed, jobs, search engine for jobs, job search engine, job listings, search jobs, career, employment, work, find jobs, rss jobs feed xml ">
# <link rel="canonical" href="/">
# <link rel="alternate" media="handheld" href="/m/">
# <link href="https://plus.google.com/113999236499154807366" rel="publisher" />
# <link rel="alternate" href="android-app://com.indeed.android.jobsearch/https/www.indeed.com/m/">
# <meta http-equiv="content-type" content="text/html; charset=utf-8">
# <style type="text/css">
# ...

# %%
tokens = [tok for tok in html.split()]
print "total number of tokens:"+ str(len(tokens))
print tokens[0:100]
# Out:
# total number of tokens:2756
# ...

# %%
import re
tokens = re.split('\W+',html)
print len(tokens)
print tokens[0:50]
# Out:
# 5941
# ['', 'DOCTYPE', 'html', 'html', 'lang', 'en', 'head', 'title', 'Job', 'Search', 'Indeed', 'title', 'meta', 'name', 'description', 'content', 'Job', 'Search', 'by', 'Indeed', 'Search', 'millions', 'of', 'jobs', 'from', 'thousands', 'of', 'job', 'boards', 'newspapers', 'classifieds', 'and', 'company', 'websites', 'on', 'indeed', 'com', 'meta', 'name', 'keywords', 'content', 'job', 'search', 'Indeed', 'jobs', 'search', 'engine', 'for', 'jobs', 'job']

# %%
import operator
freq_dis={}
for tok in tokens:
    if tok in freq_dis:
        freq_dis[tok]+=1
    else:
        freq_dis[tok]=1
sorted_freq_dist=sorted(freq_dis.items(), key=operator.itemgetter(1), reverse= True)
print sorted_freq_dist[:25]
# Out:
# [('color', 347), ('jasxcolorcontrasttst', 296), ('666', 188), ('a', 150), ('greyOnly', 98), ('blueOnly', 98), ('greyAndBlue', 98), ('0', 96), ('border', 80), ('div', 68), ('visited', 57), ('label', 53), ('sl', 52), ('top', 51), ('text', 47), ('class', 46), ('span', 46), ('script', 45), ('bottom', 45), ('link', 44), ('background', 43), ('footer', 40), ('indeed', 38), ('td', 37), ('href', 36)]

# %%
import re
tokens = re.split('\W+',raw)
print len(tokens)
print tokens[0:50]
# Out:
# 9019
# ['CHAPTER', '1', 'THE', 'PURPOSE', 'OF', 'RESEARCH', 'Chapter', 'Outline', 'Scientific', 'Research', 'and', 'Its', 'Purpose', 'Theories', 'of', 'Knowledge', 'Karl', 'Popper', 's', 'Falsifiability', 'Thomas', 'Kuhn', 's', 'Structure', 'of', 'Scientific', 'Revolution', 'A', 'Quick', 'Look', 'at', 'Qualitative', 'Quantitative', 'and', 'Mixed', 'Methods', 'Qualitative', 'Research', 'Quantitative', 'Research', 'Mixed', 'Methods', 'Ethical', 'Research', 'Ethical', 'Rules', 'A', 'Violation', 'of', 'Ethics']

# %%
#finding the highest frequency distribution
import operator
freq_dis={}
for tok in tokens:
    if tok in freq_dis:
        freq_dis[tok]+=1
    else:
        freq_dis[tok]=1
sorted_freq_dist=sorted(freq_dis.items(), key=operator.itemgetter(1), reverse= True)
print sorted_freq_dist[:50]
# Out:
# [('the', 397), ('of', 341), ('and', 245), ('to', 243), ('a', 216), ('is', 154), ('that', 148), ('we', 139), ('in', 129), ('as', 84), ('research', 83), ('are', 79), ('knowledge', 77), ('on', 63), ('with', 61), ('or', 59), ('from', 57), ('be', 55), ('new', 49), ('it', 49), ('our', 47), ('how', 46), ('not', 45), ('this', 45), ('study', 44), ('can', 44), ('for', 43), ('about', 41), ('s', 39), ('researcher', 38), ('an', 37), ('The', 36), ('were', 35), ('you', 35), ('will', 34), ('science', 31), ('what', 29), ('information', 29), ('by', 29), ('some', 27), ('us', 27), ('have', 27), ('paradigm', 26), ('at', 26), ('It', 25), ('scientific', 25), ('specific', 24), ('data', 24), ('This', 24), ('your', 23)]

# %%
import nltk
Freq_dist_nltk = nltk.FreqDist(tokens)
print Freq_dist_nltk.items()
for k,v in Freq_dist_nltk.items():
    print str(k)+':'+ str(v)
# Out:
# [('', 1), ('child', 1), ('desirable', 1), ('four', 1), ('Weislogel', 1), ('sleep', 7), ('hanging', 1), ('consists', 3), ('whose', 1), ('Ronald', 1), ('Western', 3), ('under', 7), ('League', 1), ('risk', 1), ('001', 1), ('every', 4), ('govern', 1), ('vast', 1), ('Thomas', 4), ('basics', 1), ('skills', 2), ('companies', 1), ('solution', 1), ('convenience', 1), ('Unanticipated', 1), ('Go', 1), ('provided', 2), ('enjoy', 1), ('monotonous', 1), ('Paintings', 1), ('tired', 2), ('guidelines', 4), ('direct', 2), ('empirical', 3), ('likely', 3), ('rigorous', 1), ('qualitatively', 1), ('estimated', 1), ('even', 5), ('established', 8), ('preferences', 4), ('incompatible', 1), ('cooking', 2), ('reasoning', 15), ('above', 1), ('designing', 1), ('new', 49), ('seeks', 1), ('told', 2), ('Sometimes', 4), ('simultaneously', 2), ('notions', 2), ('TT1', 2), ('error', 1), ('here', 17), ('anthropology', 2), ('protection', 1), ('studio', 2), ('possibility', 2), ('100', 1), ('interpret', 1), ('substance', 1
# ...

# %%
Freq_dist_nltk.plot(25, cumulative=False)

# %%
from nltk.corpus import stopwords
stopwords = [word.strip().lower() for word in open ('Ch_01_dropbox.txt')]
clean_tokens=[tok for tok in tokens if len(tok.lower())>1 and (tok.lower() not in stopwords)]
Freq_dist_nltk=nltk.FreqDist(clean_tokens)
Freq_dist_nltk.plot(30, cumulative = False)

# %%
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
new = [i for i in raw.lower().split() if i not in stop]
Freq_dist_nltk=nltk.FreqDist(new)
Freq_dist_nltk.plot(30, cumulative = False)

# %%
dt = open('abstract.txt')
dt = dt.read()

# %%
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
new = [i for i in dt.lower().split() if i not in stop]
Freq_dist_nltk=nltk.FreqDist(new)
Freq_dist_nltk.plot(30, cumulative = False)

# %%
import csv
with open('student_raw_file.csv', 'rU') as csvfile:
    csvreader = csv.reader(csvfile)
    for line in csvreader:
        print line[1]
# Out:
# How much do you weigh in lbs (approximately)?
# 160
# 160
# 145
# 264
# 175
#
# 150
# 140
# 195
# 170
# 155
# 145
# 135
# 200
# 155
# 128
# 140
# 180
# 125
# 155
# 155
# 167
# 165
# 170
# 120
# 165
# 128
# 135
# 112
# 180
# 125
# 125
# Not sure, 240
# 170
# 175
# 180
# 210
# 135
# 180
# 132
# 210
# 140
# 113
# 185
# 190
# 190
# 200
# 150
# 120
# 165 lbs
# 140
# 200
# 156
# 135
# 113
# 105
# 135
# 170
# 170
# 125
# 185
# 184
# 135
# 145
# 185
# 118
# 110
# 130
# 155
# 165
# 180
# 187
# 138
# 150
# 148
# 120
# 180
# 116
# 140
# 123
# 168
# 135
# 129
# 200
# 144 lbs
# 130
# 125
# 150
# 150
# 140
# 140
# 175
# 125
# 168
# 160
# 170
# 124
# 150
# 165
# 154
# 130
# 155
# 169
# 155lbs
# 178
# 265
# 150
# 175
# 190
# 100
# 240
# 135
# 115
# 174
# 150
# 185
# 135
# 175
# 208
# 145
# 140
# 140
#
# 190
# 180
# 230
# 125
# 190
# 135
# 127
# 165
# 120
# 135lbs
# 175
# 205
# 140
# 180
# 185
# 180
# 160
# 165
# 130
# 140
# 167
# 158
# 150
# 140
# 180
# 170
# 130
# 192
# 155
# 129
# 123
# 180
# ...

# %%
import json

# %%
fjali = 'Nje fjali cfaredo. Kjo eshte nje fjali. Nje fjali me germa te kuqe'

# %%
from nltk.tokenize import sent_tokenize
all_sent = sent_tokenize(fjali)
print all_sent
# Out:
# ['Nje fjali cfaredo.', 'Kjo eshte nje fjali.', 'Nje fjali me germa te kuqe']

# %%
from nltk.tokenize import sent_tokenize
all_sent = sent_tokenize(dt)
print all_sent[1:3]
# Out:
# ['Abstract:\rThe effects of exercise on depression have been a source of contentious debate.', 'Meta-analyses have demonstrated a range of effect sizes.']

# %%
disa = "hello! kush je ti? une jam maia."

# %%
print disa.split()
# Out:
# ['hello!', 'kush', 'je', 'ti?', 'une', 'jam', 'maia.']

# %%
from nltk.tokenize import word_tokenize

# %%
token=word_tokenize(disa)

# %%
from nltk.tokenize import regexp_tokenize, wordpunct_tokenize, blankline_tokenize

# %%
regexp_tokenize(disa,pattern='\w+')#all the words
# Out:
# ['hello', 'kush', 'je', 'ti', 'une', 'jam', 'maia']

# %%
kot = 'Maia eshte 3 vjec.'

# %%
regexp_tokenize(kot, pattern ='\d+')#for digits
# Out:
# ['3']

# %%
wordpunct_tokenize(disa)
# Out:
# ['hello', '!', 'kush', 'je', 'ti', '?', 'une', 'jam', 'maia', '.']

# %%
blankline_tokenize(disa)
# Out:
# ['hello! kush je ti? une jam maia.']

# %%
#first, import Porter stemmer
from nltk.stem import PorterStemmer
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem.snowball import SnowballStemmer
pst = PorterStemmer()
lst = LancasterStemmer()

# %%
lst.stem("eating")
# Out:
# 'eat'

# %%
pst.stem("shopping")
# Out:
# u'shop'

# %%
pst.stem("singing")
# Out:
# u'sing'

# %%
lst.stem("facilitate")
# Out:
# 'facilit'

# %%
from nltk.stem import WordNetLemmatizer

# %%
wlem=WordNetLemmatizer()
wlem.lemmatize("ate")
# Out:
# 'ate'

# %%
wlem.lemmatize("timeb")
# Out:
# 'timeb'

# %%
from nltk.corpus import stopwords

# %%
stoplist = stopwords.words('english')

# %%
text = "This is just a test research"

# %%
cleanwordlist = [word for word in text.split() if word not in stoplist]

# %%
print cleanwordlist
# Out:
# ['This', 'test', 'research']

# %%
freq_dist = nltk.FreqDist(dt)
rarewords = freq_dist.keys()
after_rare_words = [word in dt not in rarewords]
print after_rare_words
# Out:
# [True]

# %%
from nltk.metrics import edit_distance

# %%
edit_distance("rain","shine")
# Out:
# 3

# %%
fjali = "I was watching TV yesterday night"

# %%
print nltk.pos_tag(word_tokenize(fjali))
# Out:
# [('I', 'PRP'), ('was', 'VBD'), ('watching', 'VBG'), ('TV', 'NN'), ('yesterday', 'NN'), ('night', 'NN')]

# %%
tagged = nltk.pos_tag(word_tokenize(fjali))

# %%
allnoun = [word for word, pos in tagged if pos in ['NN','NNP']]

# %%
print allnoun
# Out:
# ['TV', 'yesterday', 'night']

# %%
from nltk.tag.stanford import StanfordPOSTagger

# %%
from nltk.corpus import brown
tags = [tag for (word, tag) in brown.tagged_words(categories='news')]

# %%
print nltk.FreqDist(tags)
# Out:
# <FreqDist with 218 samples and 100554 outcomes>

# %%
brown_tagged_sents = brown.tagged_sents(categories='news')

# %%
default_tagger=nltk.DefaultTagger('NN')

# %%
print default_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.130894842572

# %%
brown_tagged_sents = brown.tagged_sents(categories = 'news')
default_tagger=nltk.DefaultTagger('NN')
print default_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.130894842572

# %%
from nltk.tag import UnigramTagger
from nltk.tag import DefaultTagger
from nltk.tag import BigramTagger
from nltk.tag import TrigramTagger
#we divide the data into a test and train sets to evaluate our taggers
train_data = brown_tagged_sents[:int(len(brown_tagged_sents)*0.9)]
test_data = brown_tagged_sents[int(len(brown_tagged_sents)*0.9):]
unigram_tagger = UnigramTagger(train_data, backoff = default_tagger)
print unigram_tagger.evaluate(test_data)
# Out:
# 0.836041064487

# %%
bigram_tagger=BigramTagger(train_data, backoff = unigram_tagger)
print bigram_tagger.evaluate(test_data)
# Out:
# 0.844911791089

# %%
trigram_tagger = TrigramTagger(train_data, backoff = bigram_tagger)
print trigram_tagger.evaluate(test_data)
# Out:
# 0.842420013954

# %%
from nltk.corpus import brown
import nltk
tags = [tag for (word, tag) in brown.tagged_words(categories = 'news')]
print nltk.FreqDist(tags)
# Out:
# <FreqDist with 218 samples and 100554 outcomes>

# %%
print tags
# Out:
# [u'AT', u'NP-TL', u'NN-TL', u'JJ-TL', u'NN-TL', u'VBD', u'NR', u'AT', u'NN', u'IN', u'NP$', u'JJ', u'NN', u'NN', u'VBD', u'``', u'AT', u'NN', u"''", u'CS', u'DTI', u'NNS', u'VBD', u'NN', u'.', u'AT', u'NN', u'RBR', u'VBD', u'IN', u'NN', u'NNS', u'CS', u'AT', u'NN-TL', u'JJ-TL', u'NN-TL', u',', u'WDT', u'HVD', u'JJ', u'NN', u'IN', u'AT', u'NN', u',', u'``', u'VBZ', u'AT', u'NN', u'CC', u'NNS', u'IN', u'AT', u'NN-TL', u'IN-TL', u'NP-TL', u"''", u'IN', u'AT', u'NN', u'IN', u'WDT', u'AT', u'NN', u'BEDZ', u'VBN', u'.', u'AT', u'NP', u'NN', u'NN', u'HVD', u'BEN', u'VBN', u'IN', u'NP-TL', u'JJ-TL', u'NN-TL', u'NN-TL', u'NP', u'NP', u'TO', u'VB', u'NNS', u'IN', u'JJ', u'``', u'NNS', u"''", u'IN', u'AT', u'JJ', u'NN', u'WDT', u'BEDZ', u'VBN', u'IN', u'NN-TL', u'NP', u'NP', u'NP', u'.', u'``', u'RB', u'AT', u'JJ', u'NN', u'IN', u'JJ', u'NNS', u'BEDZ', u'VBN', u"''", u',', u'AT', u'NN', u'VBD', u',', u'``', u'IN', u'AT', u'JJ', u'NN', u'IN', u'AT', u'NN', u',', u'AT', u'NN', u'IN', u'NNS', u'CC
# ...

# %%
from nltk.tag.sequential import RegexpTagger

# %%
regexp_tagger=RegexpTagger([(r'^-?[0-9]+(.[0-9]+)?$','CD'),
#cardinal numbers
(r'(The|the|A|a|An|an)$','AT'),
#articles
(r'.*able$','JJ'),
#adjectives
(r'.*ness$','NN'),
#nouns formed from adj
(r'.*ly$','RB'),
#adverbs
(r'.*s$', 'NNS'),
#plural nouns
(r'.*ing$', 'VBG'),
#gerund
(r'.*ed$', 'VBD'),
#past tense verbs
(r'.*', 'NN')])
#nouns default
print regexp_tagger.evaluate(test_data)
# Out:
# 0.313066879298

# %%
from nltk import ne_chunk
sent = "Maia, mama, and papa are moving to Columbus in August"
print (ne_chunk(nltk.pos_tag(word_tokenize(sent)), binary = False))
# Out:
# (S
#   (GPE Maia/NNP)
#   ,/,
#   mama/NN
#   ,/,
#   and/CC
#   papa/NNS
#   are/VBP
#   moving/VBG
#   to/TO
#   (GPE Columbus/NNP)
#   in/IN
#   (GPE August/NNP))

# %%
from nltk import ne_chunk
sent = "Maia, mama, and papa are moving to Columbus in August"
print (ne_chunk(nltk.pos_tag(word_tokenize(sent)), binary = True))
# Out:
# (S
#   (NE Maia/NNP)
#   ,/,
#   mama/NN
#   ,/,
#   and/CC
#   papa/NNS
#   are/VBP
#   moving/VBG
#   to/TO
#   (NE Columbus/NNP)
#   in/IN
#   August/NNP)

# %%
from nltk.tag.stanford import StanfordNERTagger

# %%
#toy CFG
from nltk import CFG

# %%
toy_grammar = nltk.CFG.fromstring(""" 
    S -> NP VP
                                VP -> V NP
                                V -> "eats"|"drinks"
                                NP -> Det N
                                Det -> "a"|"an"|"the"
                                N -> "president"|"Trump"|"apple"|"coke" """)
toy_grammar.productions()
# Out:
# [S -> NP VP,
#  VP -> V NP,
#  V -> 'eats',
#  V -> 'drinks',
#  NP -> Det N,
#  Det -> 'a',
#  Det -> 'an',
#  Det -> 'the',
#  N -> 'president',
#  N -> 'Trump',
#  N -> 'apple',
#  N -> 'coke']

# %%
#regex parser
from nltk.chunk.regexp import *
chunk_rules = ChunkRule("<.*>+","chunk everything")

# %%
reg_parser = RegexpParser(""" NP:{<DT>?<JJ>*<NN>*}
P:{<IN>} 
V:{<V.*>} 
PP:{<P> <NP>} 
VP:{<V> <NP|PP>*}
""")

# %%
test_sent = "Mr. Trump played a big role in the Health Insurance bill"
test_sent_pos = nltk.pos_tag(nltk.word_tokenize(test_sent))
paresed_out = reg_parser.parse(test_sent_pos)

# %%
print paresed_out
# Out:
# (S
#   Mr./NNP
#   Trump/NNP
#   (VP
#     (V played/VBD)
#     (NP a/DT big/JJ role/NN)
#     (PP (P in/IN) (NP the/DT)))
#   Health/NNP
#   Insurance/NNP
#   (NP bill/NN))

# %%
paresed_out.draw()

# %%
from nltk.parse.stanford import StanfordParser

# %%
import os
from nltk.parse import stanford
english_parser = os.environ['STANFORD_PARSER'] = '/path/to/standford/jars'
stanford_models=os.environ['STANFORD_MODELS'] = '/path/to/standford/jars'

# %%
from nltk.chunk.regexp import *

# %%
test_sent = "I will go and pick up Maia from schoom right now. She goes to school every day at 9:00am and I pick her up around 4:00pm or 5:00pm. Maia goes to Montessori in the Woods school. She truly loves it there and has learned quite a lot"

# %%
test_sent_pos = nltk.pos_tag(nltk.word_tokenize(test_sent))

# %%
rule_vp=ChunkRule(r'(<VB.*>)?(<VB.*>)+(<PRP>)?','Chunk VPs')
